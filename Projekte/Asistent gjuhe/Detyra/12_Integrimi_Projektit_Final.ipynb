# %% [markdown]
# # Detyra 12 — Integrimi i Projektit Final
#
# Qëllimi: të bashkoni të gjitha:
# - data ingestion
# - semantic chunking
# - vector DB
# - RAG answer + citations
# - safety filter
# - evaluation mbi benchmark
#
# Në fund, paraqisni një demo dhe raport të shkurtër.

# %%
# === Setup (run this cell first) ===
import os, json, re, math, random
from pathlib import Path

PROJECT_ROOT = Path("/content")  # In Colab, students will upload the project folder or mount Drive
DOCS_DIR = PROJECT_ROOT / "documents"
QA_PATH = PROJECT_ROOT / "qa" / "qa_benchmark_40.json"

print("Docs dir:", DOCS_DIR)
print("QA path:", QA_PATH)

# Tip: If you're using Google Drive:
# from google.colab import drive
# drive.mount('/content/drive')
# PROJECT_ROOT = Path('/content/drive/MyDrive/<YOUR_PROJECT_FOLDER>')

# %% [markdown]
# ## Checklist finale
# - [ ] Segmentues semantik (fraza/dialog/gabime/terma)
# - [ ] Embeddings + index
# - [ ] Answer generator me citime
# - [ ] Refusal policy
# - [ ] Safety filter
# - [ ] Evaluation metrics
# - [ ] UI/API

# %% [markdown]
# ## Skeleton pipeline
# **TODO:** plotësoni funksionet me implementimet tuaja nga javët e mëparshme.

# %%
def ingest_documents():
    # TODO
    return []

def build_index(records):
    # TODO
    return None

def retrieve(index, query):
    # TODO
    return []

def generate_answer(query, hits):
    # TODO
    return ""

def run_evaluation():
    # TODO
    return {}

print("Fill TODOs and run your final demo.")

# %% [markdown]
# ## Dorëzimi
# - Notebook i plotësuar
# - Link/Video e demo-s (nëse kërkohet)
# - Raport 1–2 faqe: çfarë funksionon, çfarë jo, dhe pse.
