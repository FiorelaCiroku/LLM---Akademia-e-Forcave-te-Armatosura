# %% [markdown]
# # Detyra 11 — Vendosja e modelit (Deployment)
#
# Qëllimi: të krijoni një API të thjeshtë (FastAPI) ose UI (Gradio).
# Në Colab: preferohet Gradio për demo.

# %%
# !pip -q install gradio
import gradio as gr

# %% [markdown]
# ## 1) Stub function
# Lidhni këtu sistemin tuaj RAG/agent.

# %%
def chat_fn(message, history):
    # TODO: call your agent_answer / answer() from prior weeks
    return "Përgjigje (stub) me citim: (Doc: MIL-ENG-001, unit: 0)"

demo = gr.ChatInterface(fn=chat_fn, title="Military English Tutor (Demo)")
demo.launch(share=False)

# %% [markdown]
# ## Dorëzimi
# - Screenshot i UI
# - Përshkrim i komponentëve
